# %%
import pandas as pd

# %%
dataframe=pd.read_csv("indianEco.csv")
pd.set_option('display.max_rows', None)  
pd.set_option('display.max_rows', None)

# %%
print(dataframe)
# Out:
#     Year Country Name  GDP (current US$)    GDP per capita (current US$)   \
# 0   1960        India        3.702988e+10                              82
# 1   1961        India        3.923244e+10                              85
# 2   1962        India        4.216148e+10                              90
# 3   1963        India        4.842192e+10                             101
# 4   1964        India        5.648029e+10                             116
# 5   1965        India        5.955485e+10                             119
# 6   1966        India        4.586546e+10                              90
# 7   1967        India        5.013494e+10                              96
# 8   1968        India        5.308546e+10                             100
# 9   1969        India        5.844800e+10                             108
# 10  1970        India        6.242248e+10                             112
# 11  1971        India        6.735099e+10                             119
# ...

# %%
print(dataframe.describe())
# Out:
#               Year  GDP (current US$)    GDP per capita (current US$)   \
# count    61.000000        6.100000e+01                       61.000000
# mean   1990.000000        6.584725e+11                      575.557377
# std      17.752934        8.129606e+11                      584.079062
# min    1960.000000        3.702988e+10                       82.000000
# 25%    1975.000000        9.952590e+10                      161.000000
# 50%    1990.000000        2.882084e+11                      340.000000
# 75%    2005.000000        8.203816e+11                      715.000000
# max    2020.000000        2.831552e+12                     2101.000000
#
#        GDP growth (annual %)  Imports of goods and services (% of GDP)  \
# count              61.000000                                 61.000000
# mean                4.938197                                 12.746393
# std                 3.344891                                  8.155110
# ...

# %%
print(dataframe.columns)
# Out:
# Index(['Year', 'Country Name', 'GDP (current US$) ',
#        ' GDP per capita (current US$) ', 'GDP growth (annual %)',
#        'Imports of goods and services (% of GDP)',
#        'Exports of goods and services (% of GDP)',
#        ' Total reserves (includes gold, current US$) ',
#        'Inflation, consumer prices (annual %)', 'Population, total',
#        'Population growth (annual %)',
#        'Life expectancy at birth, total (years)'],
#       dtype='object')

# %%
print(dataframe["GDP (current US$) "])
# Out:
# 0     3.702988e+10
# 1     3.923244e+10
# 2     4.216148e+10
# 3     4.842192e+10
# 4     5.648029e+10
# 5     5.955485e+10
# 6     4.586546e+10
# 7     5.013494e+10
# 8     5.308546e+10
# 9     5.844800e+10
# 10    6.242248e+10
# 11    6.735099e+10
# 12    7.146319e+10
# 13    8.551527e+10
# 14    9.952590e+10
# 15    9.847280e+10
# 16    1.027172e+11
# 17    1.214873e+11
# 18    1.373003e+11
# 19    1.529917e+11
# 20    1.863253e+11
# 21    1.934906e+11
# 22    2.007151e+11
# 23    2.182623e+11
# 24    2.121582e+11
# 25    2.325119e+11
# 26    2.489860e+11
# 27    2.790336e+11
# 28    2.965890e+11
# 29    2.960424e+11
# 30    3.209790e+11
# 31    2.701053e+11
# 32    2.882084e+11
# 33    2.792960e+11
# 34    3.272756e+11
# 35    3.602820e+11
# 36    3.928971e+11
# 37    4.158678e+11
# 38    4.213515e+11
# 39    4.588204e+11
# 40    4.683949e+11
# 41    4.854410e+11
# 42    5.149379e+11
# 43    6.076993e+11
# 44    7.091485e+11
# 45    8.203816e+11
# 46    9.402599e+11
# ...

# %%
print(dataframe["Year"])b
# Out:
# 0     1960
# 1     1961
# 2     1962
# 3     1963
# 4     1964
# 5     1965
# 6     1966
# 7     1967
# 8     1968
# 9     1969
# 10    1970
# 11    1971
# 12    1972
# 13    1973
# 14    1974
# 15    1975
# 16    1976
# 17    1977
# 18    1978
# 19    1979
# 20    1980
# 21    1981
# 22    1982
# 23    1983
# 24    1984
# 25    1985
# 26    1986
# 27    1987
# 28    1988
# 29    1989
# 30    1990
# 31    1991
# 32    1992
# 33    1993
# 34    1994
# 35    1995
# 36    1996
# 37    1997
# 38    1998
# 39    1999
# 40    2000
# 41    2001
# 42    2002
# 43    2003
# 44    2004
# 45    2005
# 46    2006
# 47    2007
# 48    2008
# 49    2009
# 50    2010
# 51    2011
# 52    2012
# 53    2013
# 54    2014
# 55    2015
# 56    2016
# 57    2017
# 58    2018
# 59    2019
# 60    2020
# Name: Year, dtype: int64

# %%
print(dataframe[["Year",'GDP (current US$) ']])
# Out:
#     Year  GDP (current US$)
# 0   1960        3.702988e+10
# 1   1961        3.923244e+10
# 2   1962        4.216148e+10
# 3   1963        4.842192e+10
# 4   1964        5.648029e+10
# 5   1965        5.955485e+10
# 6   1966        4.586546e+10
# 7   1967        5.013494e+10
# 8   1968        5.308546e+10
# 9   1969        5.844800e+10
# 10  1970        6.242248e+10
# 11  1971        6.735099e+10
# 12  1972        7.146319e+10
# 13  1973        8.551527e+10
# 14  1974        9.952590e+10
# 15  1975        9.847280e+10
# 16  1976        1.027172e+11
# 17  1977        1.214873e+11
# 18  1978        1.373003e+11
# 19  1979        1.529917e+11
# 20  1980        1.863253e+11
# 21  1981        1.934906e+11
# 22  1982        2.007151e+11
# 23  1983        2.182623e+11
# 24  1984        2.121582e+11
# 25  1985        2.325119e+11
# 26  1986        2.489860e+11
# 27  1987        2.790336e+11
# 28  1988        2.965890e+11
# 29  1989        2.960424e+11
# 30  1990        3.209790e+11
# ...

# %%
dataframe.rename(columns={"GDP (current US$) ": 'GDP$'}, inplace=True)

# %%
print(dataframe.columns)
# Out:
# Index(['Year', 'Country Name', 'GDP$', ' GDP per capita (current US$) ',
#        'GDP growth (annual %)', 'Imports of goods and services (% of GDP)',
#        'Exports of goods and services (% of GDP)',
#        ' Total reserves (includes gold, current US$) ',
#        'Inflation, consumer prices (annual %)', 'Population, total',
#        'Population growth (annual %)',
#        'Life expectancy at birth, total (years)'],
#       dtype='object')

# %%
df_selected = dataframe[['Year', 'GDP$']]

# %%
print(df_selected)
# Out:
#     Year          GDP$
# 0   1960  3.702988e+10
# 1   1961  3.923244e+10
# 2   1962  4.216148e+10
# 3   1963  4.842192e+10
# 4   1964  5.648029e+10
# 5   1965  5.955485e+10
# 6   1966  4.586546e+10
# 7   1967  5.013494e+10
# 8   1968  5.308546e+10
# 9   1969  5.844800e+10
# 10  1970  6.242248e+10
# 11  1971  6.735099e+10
# 12  1972  7.146319e+10
# 13  1973  8.551527e+10
# 14  1974  9.952590e+10
# 15  1975  9.847280e+10
# 16  1976  1.027172e+11
# 17  1977  1.214873e+11
# 18  1978  1.373003e+11
# 19  1979  1.529917e+11
# 20  1980  1.863253e+11
# 21  1981  1.934906e+11
# 22  1982  2.007151e+11
# 23  1983  2.182623e+11
# 24  1984  2.121582e+11
# 25  1985  2.325119e+11
# 26  1986  2.489860e+11
# 27  1987  2.790336e+11
# 28  1988  2.965890e+11
# 29  1989  2.960424e+11
# 30  1990  3.209790e+11
# 31  1991  2.701053e+11
# 32  1992  2.882084e+11
# 33  1993  2.792960e+11
# 34  1994  3.272756e+11
# 35  1995  3.602820e+11
# 36  1996  3.928971e+11
# 37  1997  4.158678e+11
# 38  1998  4.213515e+11
# ...

# %%
df_selected.to_csv('yearandgdp.csv', index=False)
